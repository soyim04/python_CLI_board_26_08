# %% [markdown]
# <a href="https://colab.research.google.com/github/soyim04/python_CLI_board_26_08/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_CLI_board.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("== CLI 게시판 실행 ==")
last_article_id = 0
articles = []

while True:
  cmd = input("명령어 ) ").strip()

  if cmd == "exit":
    break

  elif cmd == "article write":
    last_article_id += 1
    id = last_article_id
    title = input("제목 : ")
    body = input("내용 : ")

    article = {"id" : id, "title" : title, "body" : body}
    articles.append(article)

    print("{}번 글이 생성되었습니다".format(last_article_id))
  elif cmd == "article list":
    if not articles:
      print("게시글이 없어")
    else:
      print("=========================================")
      print("   번호      /     제목       /     내용    ")
      for a in reversed(articles):
        print("    {}      /     {}       /     {}    ".format(a["id"],a["title"],a["body"]))
      print("=========================================")
  elif cmd.startswith("article delete"):
    cmdBits = cmd.split(" ")

    if len(cmdBits) < 3:
      print("명령어 똑바로 써라(길이 모자람)")
      continue

    if not cmdBits[2].isdigit() :
      print("명령어 똑바로 써라(번호 대신 str 있는듯?)")
      continue

    # 이 부분까지 왔다는거는 '명령어 입력을 잘 했다'의 상황
    # print(1)
    for article in articles:
      # print(2)
      # print("article['id'] : {}".format(article["id"]))
      # print("cmdBits[2] : {}".format(cmdBits[2]))
      # print("type(article['id']) : {}".format(type(article['id'])))
      # print("type(cmdBits[2]) : {}".format(type(cmdBits[2])))
      if article["id"] == int(cmdBits[2]):
        # print(3)
        articles.remove(article)
        print("{}번 글 삭제됨".format(cmdBits[2]))
        break

  else:
    print("지원하지 않는 명령어입니다.")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : a
# 내용 : a
# 1번 글이 생성되었습니다
# 명령어 ) article write
# 제목 : b
# 내용 : b
# 2번 글이 생성되었습니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#     2      /     b       /     b
#     1      /     a       /     a
# ...
# 명령어 ) article delete 3
# 명령어 ) article delete 2
# 2번 글 삭제됨
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#     1      /     a       /     a
# ...
# 명령어 ) article write
# 제목 : abcde
# 내용 : ggg
# 3번 글이 생성되었습니다
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#     3      /     abcde       /     ggg
#     1      /     a       /     a
# ...
# 명령어 ) article delete 3
# 3번 글 삭제됨
# 명령어 ) article list
# ...
#    번호      /     제목       /     내용
#     1      /     a       /     a
# ...
# 명령어 ) exit
# == CLI 게시판 종료 ==
